# %% [markdown]
# # SVM   ---> classification if iris data

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sn.load_dataset('iris')
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %% [markdown]
# ### Label Encoder ka  use krke speces ko    0 1 2 me convert kaernge

# %%
from sklearn.preprocessing import LabelEncoder
le_species = LabelEncoder()

# %% [markdown]
# ### ek  new column (target) add karenge aur usme species ke no ko rakhenge

# %%
df['Target'] = le_species.fit_transform(df['species'])

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  Target
# 0             5.1          3.5           1.4          0.2     setosa       0
# 1             4.9          3.0           1.4          0.2     setosa       0
# 2             4.7          3.2           1.3          0.2     setosa       0
# 3             4.6          3.1           1.5          0.2     setosa       0
# 4             5.0          3.6           1.4          0.2     setosa       0
# ..            ...          ...           ...          ...        ...     ...
# 145           6.7          3.0           5.2          2.3  virginica       2
# 146           6.3          2.5           5.0          1.9  virginica       2
# 147           6.5          3.0           5.2          2.0  virginica       2
# 148           6.2          3.4           5.4          2.3  virginica       2
# 149           5.9          3.0           5.1          1.8  virginica       2
#
# [150 rows x 6 columns]

# %%
df0 = df[:50]
df1 = df[51:100]
df2 = df[101 :]

# %%
plt.figure(figsize = (7,5))
plt.xlabel('sepal_length')
plt.xlabel('sepal_width')

plt.scatter(df0['sepal_length'], df0['sepal_width'], label = 'setosa', marker = '*')
plt.scatter(df1['sepal_length'], df1['sepal_width'], label =  'versicolor')
plt.legend()

# %%
plt.figure(figsize = (7,5))
plt.xlabel('petal_length')
plt.xlabel('petal_width')

plt.scatter(df0['petal_length'], df0['petal_width'], label = 'setosa', marker = '*')
plt.scatter(df1['petal_length'], df1['petal_width'], label =  'versicolor')
plt.legend()

# %% [markdown]
# #### X  &  Y decide Karenge

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species, Target]
# Index: []

# %%
x = df.iloc[: , :4]
y = df.Target

# %% [markdown]
# ## Data ko Train  &  Test  me Divide karenge

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2 )

# %%
len(x_train)
# Out:
# 120

# %%
len(x_test)
# Out:
# 30

# %% [markdown]
# ## ab  SVM  algorithm ka use krenge

# %%
from sklearn.svm import SVC
model = SVC()

# %% [markdown]
# ### ab model ko Data dal kr train karenege

# %%
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
model.score(x_test, y_test)
# Out:
# 0.9333333333333333

# %%
x_test.head(4)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 49           5.0          3.3           1.4          0.2
# 7            5.0          3.4           1.5          0.2
# 32           5.2          4.1           1.5          0.1
# 15           5.7          4.4           1.5          0.4

# %%
model.predict([[4.5, 3.3, 3 ,1]])
# Out:
# array([1])

# %%
sn.pairplot(df, hue = 'species')
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\anaconda\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\anaconda\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
